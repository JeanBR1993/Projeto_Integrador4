# %%
# Carrega os dados já limpos e prontos de acordo com a análise exploratoria para serem usados

from src.preparo import carregar_particao

X_treino, X_teste, y_treino, y_teste = carregar_particao()
